# %% [markdown]
# Here datasets not yet in right format get transformed to right format for evaluation

# %%
import pandas as pd

# Load CSV
df = pd.read_csv("18-5 VAE 1 start curve.csv")

# Remove 2nd and 3rd columns
df = df.drop(df.columns[[2]], axis=1)

# Save new CSV
df.to_csv("18-5 VAE 1 start curve right format.csv", index=False)
