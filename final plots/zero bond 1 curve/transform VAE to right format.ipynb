# %% [markdown]
# Here datasets not yet in right format get transformed to right format for evaluation

# %%
import pandas as pd

# Load CSV
df = pd.read_csv("12-8 4.0 (900 epochs) generated_yield_curve_scenarios.csv")

# Remove 3rd column
df = df.drop(df.columns[[2]], axis=1)

# Save new CSV
df.to_csv("12-8 4.0 (900 epochs) generated_yield_curve_scenarios_right_format.csv", index=False)
