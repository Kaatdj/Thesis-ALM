# %% [markdown]
# ### ideas
# - calculate volatility variation on shorter term and long term, these variantion should be found back in generated data
# - hump shape (visually okay, but how do we do this quantitively)
